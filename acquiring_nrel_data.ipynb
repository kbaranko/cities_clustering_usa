# %% [markdown]
# Import necessary packages, define API key, and connect to database in order to pull list of 5,000 most populous cities in the US.

# %%
import requests
import config
import json

# %%
api_key = config.api_key

# %%
db_name = 'City_Energy_Data'
import mysql.connector
import config

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.passwd,
    database = db_name
)
cur = cnx.cursor()

# %%
cur.execute("""SELECT *
                      FROM population_data
                    ;""")
pop_data = cur.fetchall()
pop_data[0:5]
# Out:
# [(1, 'New York ', 'NY', '8,363,710'),
#  (2, 'Los Angeles ', 'CA', '3,833,995'),
#  (3, 'Chicago ', 'IL', '2,853,114'),
#  (4, 'Houston ', 'TX', '2,242,193'),
#  (5, 'Phoenix ', 'AZ', '1,567,924')]

# %% [markdown]
# Loop through list to isolate city name and city state.

# %%
city_names = []
for city in pop_data:
    name = city[1]
    name = name.strip()
    city_names.append(name)

# %%
city_states = []
for city in pop_data:
    state = city[2]
    state = state.strip()
    city_states.append(state)
len(city_states)
# Out:
# 5000

# %% [markdown]
# Create tables for residential, commercial, and industrial energy data with city_id as primary key.

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.passwd,
    database = db_name
)
cur = cnx.cursor()

# %%
tables_res = {}
tables_res['residential_energy_A'] = (
    """CREATE TABLE residential_energy_A (
       housing_units int(40) ,
       elec_mwh int(40),
       gas_mcf int(40),
       elec_lb_ghg int(40),
       gas_lb_ghg int(40),
       city varchar(40),
       state varchar(40),
       city_id int(40),
       PRIMARY KEY (city_id))"""
)

# %%
tables_com = {}
tables_com['commercial_energy_A'] = (
    """CREATE TABLE commercial_energy_A (
       num_establishments int(40) ,
       elec_mwh int(40),
       gas_mcf int(40),
       elec_lb_ghg int(40),
       gas_lb_ghg int(40),
       city varchar(40),
       state varchar(40),
       city_id int(40),
       PRIMARY KEY (city_id))"""
)

# %%
tables_ind = {}
tables_ind['industrial_energy_A'] = (
    """CREATE TABLE industrial_energy_A (
       num_establishments int(40) ,
       elec_mwh int(40),
       gas_mcf int(40),
       elec_lb_ghg int(40),
       gas_lb_ghg int(40),
       city varchar(40),
       state varchar(40),
       city_id int(40),
       PRIMARY KEY (city_id))"""
)

# %%
tables_res['residential_energy_A']

# %%
cur.execute(tables_res['residential_energy_A'])
cnx.commit()

# %%
cur.execute(tables_com['commercial_energy_A'])
cnx.commit()

# %%
cur.execute(tables_ind['industrial_energy_A'])
cnx.commit()

# %%
cnx.close()

# %% [markdown]
# Loop list of cities and states through get_energy_info function to obtain residential, commercial, and industrial energy data for each city. Given the 1,000 API calls per hour limit, loop through cities as groups of 500.

# %%
energy_data_1 = []
for x, y in zip(city_names[0:50], city_states[0:50]):
    output = get_energy_info(x, y)
    energy_data_1.append(output)

# %% [markdown]
# Check results. City energy data should be a list of tuples, with each tuple containing three dictionaries.

# %%
energy_data_1
# Out:
# [({'housing_units': 3128246,
#    'elec_mwh': 14872960,
#    'gas_mcf': 179425068,
#    'elec_lb_ghg': 22285615334,
#    'gas_lb_ghg': 21538668054,
#    'city': 'New York',
#    'state': 'NY'},
#   {'num_establishments': 92276,
#    'elec_mwh': 26024809,
#    'gas_mcf': 97518263,
#    'elec_lb_ghg': 38995524672,
#    'gas_lb_ghg': 11706354721,
#    'city': 'New York',
#    'state': 'NY'},
#   {'num_establishments': 26376,
#    'elec_mwh': 1245512,
#    'gas_mcf': 5426336,
#    'elec_lb_ghg': 1866272757,
#    'gas_lb_ghg': 651391971,
#    'city': 'New York',
#    'state': 'NY'}),
#  ({'housing_units': 1355074,
#    'elec_mwh': 9043891,
#    'gas_mcf': 41818846,
#    'elec_lb_ghg': 12109857609,
#    'gas_lb_ghg': 5020046832,
#    'city': 'Los Angeles',
#    'state': 'CA'},
#   {'num_establishments': 49649,
#    'elec_mwh': 12023369,
#    'gas_mcf': 14889777,
#    'elec_lb_ghg': 16099407399,
#    'gas_lb_ghg': 1787408917,
#    'city': 'Los Angeles',
#    'state': 'CA'},
#   {'num_establishments': 24184,
#    'elec_mwh': 2288471,
#    'gas_mcf': 34767844,
#    'elec_lb_ghg': 3064284770,
#    'gas_lb_ghg': 4173625595,
#    'city': 'Los Angeles',
#    'state': 'CA'}),
#  ({'housing_units': 1042539,
#    'elec_mwh': 7211287,
#    'gas_mcf': 90027429,
#    'elec_lb_ghg': 12294477691,
#    'gas_lb_ghg': 10807134902,
#    'city': 'Chicago',
#    'state': 'IL'},
#   {'num_establishments': 38486,
#    'elec_mwh': 6145963,
#    'gas_mcf': 28559474,
#    'elec_lb_ghg': 10478212549,
#    'gas_lb_ghg': 3428356144,
#    'city': 'Chicago',
#    'state': 'IL'},
#   {'num_establishments': 8648,
#    'elec_mwh': 4386519,
#    'gas_mcf': 25604317,
#    'elec_lb_ghg': 7478548883,
#    'gas_lb_ghg': 3073611091,
#    'city': 'Chicago',
#    'state': 'IL'}),
#  ({'housing_units': 829402,
#    'elec_mwh': 10547389,
#    'gas_mcf': 12930383,
#    'elec_lb_ghg': 14122966039,
#    'gas_lb_ghg': 1552197921,
#    'city': 'Houston',
#    'state': 'TX'},
#   {'num_establishments': 32886,
#    'elec_mwh': 10141135,
#    'gas_mcf': 13429153,
#    'elec_lb_ghg': 13578992566,
#    'gas_lb_ghg': 1612071631,
#    'city': 'Houston',
#    'state': 'TX'},
#   {'num_establishments': 14747,
#    'elec_mwh': 9948073,
#    'gas_mcf': 144722117,
#    'elec_lb_ghg': 13320481119,
#    'gas_lb_ghg': 17372832501,
#    'city': 'Houston',
#    'state': 'TX'}),
#  ({'housing_units': 537950,
#    'elec_mwh': 7371754,
#    'gas_mcf': 5608729,
#    'elec_lb_ghg': 9467690048,
#    'gas_lb_ghg': 673286920,
#    'city': 'Phoenix',
#    'state': 'AZ'},
#   {'num_establishments': 17682,
#    'elec_mwh': 5631927,
#    'gas_mcf': 4860398,
#    'elec_lb_ghg': 7233194938,
#    'gas_lb_ghg': 583455302,
#    'city': 'Phoenix',
#    'state': 'AZ'},
#   {'num_establishments': 5993,
#    'elec_mwh': 2924831,
#    'gas_mcf': 3860128,
#    'elec_lb_ghg': 3756417973,
#    'gas_lb_ghg': 463380159,
#    'city': 'Phoenix',
#    'state': 'AZ'}),
#  ({'housing_units': 582511,
#    'elec_mwh': 4271528,
#    'gas_mcf': 33972181,
#    'elec_lb_ghg': 8231817377,
#    'gas_lb_ghg': 4078112104,
#    'city': 'Philadelphia',
#    'state': 'PA'},
#   {'num_establishments': 22776,
#    'elec_mwh': 2433317,
#    'gas_mcf': 12741188,
#    'elec_lb_ghg': 4689334855,
#    'gas_lb_ghg': 1529486505,
#    'city': 'Philadelphia',
#    'state': 'PA'},
#   {'num_establishments': 3361,
#    'elec_mwh': 2001505,
#    'gas_mcf': 9014290,
#    'elec_lb_ghg': 3857173475,
#    'gas_lb_ghg': 1082099587,
#    'city': 'Philadelphia',
#    'state': 'PA'}),
#  ({'housing_units': 490706,
#    'elec_mwh': 6367743,
#    'gas_mcf': 7642157,
#    'elec_lb_ghg': 8526415165,
#    'gas_lb_ghg': 917385060,
#    'city': 'San Antonio',
#    'state': 'TX'},
#   {'num_establishments': 16701,
#    'elec_mwh': 5290272,
#    'gas_mcf': 8468865,
#    'elec_lb_ghg': 7083680435,
#    'gas_lb_ghg': 1016625382,
#    'city': 'San Antonio',
#    'state': 'TX'},
#   {'num_establishments': 6816,
#    'elec_mwh': 2389252,
#    'gas_mcf': 34758244,
#    'elec_lb_ghg': 3199210631,
#    'gas_lb_ghg': 4172473196,
#    'city': 'San Antonio',
#    'state': 'TX'}),
#  ({'housing_units': 487279,
#    'elec_mwh': 5908317,
#    'gas_mcf': 11271294,
#    'elec_lb_ghg': 7911244137,
#    'gas_lb_ghg': 1353036466,
#    'city': 'Dallas',
#    'state': 'TX'},
#   {'num_establishments': 18628,
#    'elec_mwh': 6829102,
#    'gas_mcf': 6807531,
#    'elec_lb_ghg': 9144175215,
#    'gas_lb_ghg': 817194383,
#    'city': 'Dallas',
#    'state': 'TX'},
#   {'num_establishments': 5837,
#    'elec_mwh': 2944917,
#    'gas_mcf': 42841934,
#    'elec_lb_ghg': 3943247772,
#    'gas_lb_ghg': 5142861016,
#    'city': 'Dallas',
#    'state': 'TX'}),
#  ({'housing_units': 490141,
#    'elec_mwh': 2370489,
#    'gas_mcf': 11195110,
#    'elec_lb_ghg': 3174108016,
#    'gas_lb_ghg': 1343891109,
#    'city': 'San Diego',
#    'state': 'CA'},
#   {'num_establishments': 15918,
#    'elec_mwh': 2311372,
#    'gas_mcf': 6075187,
#    'elec_lb_ghg': 3094949699,
#    'gas_lb_ghg': 729281807,
#    'city': 'San Diego',
#    'state': 'CA'},
#   {'num_establishments': 5786,
#    'elec_mwh': 1871437,
#    'gas_mcf': 28432012,
#    'elec_lb_ghg': 2505872435,
#    'gas_lb_ghg': 3413055286,
#    'city': 'San Diego',
#    'state': 'CA'}),
#  ({'housing_units': 317315,
#    'elec_mwh': 1850979,
#    'gas_mcf': 10113753,
#    'elec_lb_ghg': 2478478685,
#    'gas_lb_ghg': 1214082180,
#    'city': 'San Jose',
#    'state': 'CA'},
#   {'num_establishments': 10458,
#    'elec_mwh': 1517782,
#    'gas_mcf': 4525170,
#    'elec_lb_ghg': 2032325340,
#    'gas_lb_ghg': 543213602,
#    'city': 'San Jose',
#    'state': 'CA'},
#   {'num_establishments': 4080,
#    'elec_mwh': 981063,
#    'gas_mcf': 14904908,
#    'elec_lb_ghg': 1313653033,
#    'gas_lb_ghg': 1789225327,
#    'city': 'San Jose',
#    'state': 'CA'}),
#  ({'housing_units': 256985,
#    'elec_mwh': 2125025,
#    'gas_mcf': 38561981,
#    'elec_lb_ghg': 2773669692,
#    'gas_lb_ghg': 4629084040,
#    'city': 'Detroit',
#    'state': 'MI'},
#   {'num_establishments': 13202,
#    'elec_mwh': 993116,
#    'gas_mcf': 0,
#    'elec_lb_ghg': 1296255508,
#    'gas_lb_ghg': 14,
#    'city': 'Detroit',
#    'state': 'MI'},
#   {'num_establishments': 1902,
#    'elec_mwh': 873081,
#    'gas_mcf': 4854812,
#    'elec_lb_ghg': 1139581957,
#    'gas_lb_ghg': 582784662,
#    'city': 'Detroit',
#    'state': 'MI'}),
#  ({'housing_units': 356797,
#    'elec_mwh': 1326629,
#    'gas_mcf': 8997304,
#    'elec_lb_ghg': 1776368995,
#    'gas_lb_ghg': 1080060601,
#    'city': 'San Francisco',
#    'state': 'CA'},
#   {'num_establishments': 14641,
#    'elec_mwh': 4236898,
#    'gas_mcf': 16310978,
#    'elec_lb_ghg': 5673247269,
#    'gas_lb_ghg': 1958013730,
#    'city': 'San Francisco',
#    'state': 'CA'},
#   {'num_establishments': 3578,
#    'elec_mwh': 118340,
#    'gas_mcf': 1797888,
#    'elec_lb_ghg': 158457972,
#    'gas_lb_ghg': 215823364,
#    'city': 'San Francisco',
#    'state': 'CA'}),
#  ({'housing_units': 322002,
#    'elec_mwh': 4430020,
#    'gas_mcf': 654575,
#    'elec_lb_ghg': 6250804825,
#    'gas_lb_ghg': 78576913,
#    'city': 'Jacksonville',
#    'state': 'FL'},
#   {'num_establishments': 14023,
#    'elec_mwh': 2593521,
#    'gas_mcf': 2734020,
#    'elec_lb_ghg': 3659484579,
#    'gas_lb_ghg': 328199150,
#    'city': 'Jacksonville',
#    'state': 'FL'},
#   {'num_establishments': 3141,
#    'elec_mwh': 916063,
#    'gas_mcf': 5666047,
#    'elec_lb_ghg': 1292574695,
#    'gas_lb_ghg': 680167516,
#    'city': 'Jacksonville',
#    'state': 'FL'}),
#  ({'city': 'Indianapolis', 'state': 'IN', 'elec_mwh': 'no_info'},
#   {'city': 'Indianapolis', 'state': 'IN', 'elec_mwh': 'no_info'},
#   {'city': 'Indianapolis', 'state': 'IN', 'elec_mwh': 'no_info'}),
#  ({'housing_units': 356573,
#    'elec_mwh': 3755068,
#    'gas_mcf': 6692579,
#    'elec_lb_ghg': 5028039909,
#    'gas_lb_ghg': 803395226,
#    'city': 'Austin',
#    'state': 'TX'},
#   {'num_establishments': 12914,
#    'elec_mwh': 4372539,
#    'gas_mcf': 5279691,
#    'elec_lb_ghg': 5854834893,
#    'gas_lb_ghg': 633788321,
#    'city': 'Austin',
#    'state': 'TX'},
#   {'num_establishments': 3284,
#    'elec_mwh': 1272853,
#    'gas_mcf': 18517156,
#    'elec_lb_ghg': 1704351957,
#    'gas_lb_ghg': 2222849220,
#    'city': 'Austin',
#    'state': 'TX'}),
#  ({'housing_units': 337840,
#    'elec_mwh': 3276817,
#    'gas_mcf': 17227496,
#    'elec_lb_ghg': 5586624575,
#    'gas_lb_ghg': 2068035032,
#    'city': 'Columbus',
#    'state': 'OH'},
#   {'num_establishments': 12716,
#    'elec_mwh': 3276695,
#    'gas_mcf': 10504445,
#    'elec_lb_ghg': 5586416625,
#    'gas_lb_ghg': 1260981809,
#    'city': 'Columbus',
#    'state': 'OH'},
#   {'num_establishments': 2257,
#    'elec_mwh': 887231,
#    'gas_mcf': 4857850,
#    'elec_lb_ghg': 1512634237,
#    'gas_lb_ghg': 583149356,
#    'city': 'Columbus',
#    'state': 'OH'}),
#  ({'housing_units': 276975,
#    'elec_mwh': 3742151,
#    'gas_mcf': 6037572,
#    'elec_lb_ghg': 5010745221,
#    'gas_lb_ghg': 724766358,
#    'city': 'Fort Worth',
#    'state': 'TX'},
#   {'num_establishments': 9552,
#    'elec_mwh': 2551870,
#    'gas_mcf': 2676614,
#    'elec_lb_ghg': 3416956492,
#    'gas_lb_ghg': 321307972,
#    'city': 'Fort Worth',
#    'state': 'TX'},
#   {'num_establishments': 4826,
#    'elec_mwh': 1901054,
#    'gas_mcf': 27656060,
#    'elec_lb_ghg': 2545512922,
#    'gas_lb_ghg': 3319907834,
#    'city': 'Fort Worth',
#    'state': 'TX'}),
#  ({'housing_units': 310181,
#    'elec_mwh': 3608718,
#    'gas_mcf': 8490675,
#    'elec_lb_ghg': 4473705831,
#    'gas_lb_ghg': 1019243520,
#    'city': 'Charlotte',
#    'state': 'NC'},
#   {'num_establishments': 11404,
#    'elec_mwh': 3639807,
#    'gas_mcf': 4741773,
#    'elec_lb_ghg': 4512246506,
#    'gas_lb_ghg': 569215248,
#    'city': 'Charlotte',
#    'state': 'NC'},
#   {'num_establishments': 3049,
#    'elec_mwh': 1149212,
#    'gas_mcf': 4435250,
#    'elec_lb_ghg': 1424670886,
#    'gas_lb_ghg': 532419387,
#    'city': 'Charlotte',
#    'state': 'NC'}),
#  ({'housing_units': 249409,
#    'elec_mwh': 3536905,
#    'gas_mcf': 11326944,
#    'elec_lb_ghg': 5928944662,
#    'gas_lb_ghg': 1359716799,
#    'city': 'Memphis',
#    'state': 'TN'},
#   {'num_establishments': 11583,
#    'elec_mwh': 2412553,
#    'gas_mcf': 4663782,
#    'elec_lb_ghg': 4044183458,
#    'gas_lb_ghg': 559852922,
#    'city': 'Memphis',
#    'state': 'TN'},
#   {'num_establishments': 2224,
#    'elec_mwh': 2421082,
#    'gas_mcf': 12642355,
#    'elec_lb_ghg': 4058481454,
#    'gas_lb_ghg': 1517622267,
#    'city': 'Memphis',
#    'state': 'TN'}),
#  ({'housing_units': 242389,
#    'elec_mwh': 2291892,
#    'gas_mcf': 12930717,
#    'elec_lb_ghg': 4416789624,
#    'gas_lb_ghg': 1552238024,
#    'city': 'Baltimore',
#    'state': 'MD'},
#   {'num_establishments': 10989,
#    'elec_mwh': 4266603,
#    'gas_mcf': 17727727,
#    'elec_lb_ghg': 8222326307,
#    'gas_lb_ghg': 2128084060,
#    'city': 'Baltimore',
#    'state': 'MD'},
#   {'num_establishments': 1635,
#    'elec_mwh': 1057131,
#    'gas_mcf': 4260618,
#    'elec_lb_ghg': 2037236141,
#    'gas_lb_ghg': 511456011,
#    'city': 'Baltimore',
#    'state': 'MD'}),
#  ({'housing_units': 219323,
#    'elec_mwh': 1665632,
#    'gas_mcf': 5555591,
#    'elec_lb_ghg': 2139203905,
#    'gas_lb_ghg': 666908154,
#    'city': 'El Paso',
#    'state': 'TX'},
#   {'num_establishments': 7976,
#    'elec_mwh': 2021119,
#    'gas_mcf': 3541208,
#    'elec_lb_ghg': 2595763540,
#    'gas_lb_ghg': 425096096,
#    'city': 'El Paso',
#    'state': 'TX'},
#   {'num_establishments': 2074,
#    'elec_mwh': 1298083,
#    'gas_mcf': 18884191,
#    'elec_lb_ghg': 1667153540,
#    'gas_lb_ghg': 2266909060,
#    'city': 'El Paso',
#    'state': 'TX'}),
#  ({'housing_units': 259324,
#    'elec_mwh': 1326018,
#    'gas_mcf': 11524244,
#    'elec_lb_ghg': 1439083261,
#    'gas_lb_ghg': 1383401249,
#    'city': 'Boston',
#    'state': 'MA'},
#   {'num_establishments': 9755,
#    'elec_mwh': 2534771,
#    'gas_mcf': 12160811,
#    'elec_lb_ghg': 2750902173,
#    'gas_lb_ghg': 1459816450,
#    'city': 'Boston',
#    'state': 'MA'},
#   {'num_establishments': 1742,
#    'elec_mwh': 231043,
#    'gas_mcf': 1407156,
#    'elec_lb_ghg': 250743393,
#    'gas_lb_ghg': 168918825,
#    'city': 'Boston',
#    'state': 'MA'}),
#  ({'housing_units': 230919,
#    'elec_mwh': 1694666,
#    'gas_mcf': 16094962,
#    'elec_lb_ghg': 2889225898,
#    'gas_lb_ghg': 1932082552,
#    'city': 'Milwaukee',
#    'state': 'WI'},
#   {'num_establishments': 8720,
#    'elec_mwh': 1717998,
#    'gas_mcf': 6465508,
#    'elec_lb_ghg': 2929003518,
#    'gas_lb_ghg': 776136993,
#    'city': 'Milwaukee',
#    'state': 'WI'},
#   {'num_establishments': 1475,
#    'elec_mwh': 989695,
#    'gas_mcf': 5896421,
#    'elec_lb_ghg': 1687324629,
#    'gas_lb_ghg': 707822293,
#    'city': 'Milwaukee',
#    'state': 'WI'}),
#  ({'housing_units': 281076,
#    'elec_mwh': 1877542,
#    'gas_mcf': 14607101,
#    'elec_lb_ghg': 3290038605,
#    'gas_lb_ghg': 1753475748,
#    'city': 'Denver',
#    'state': 'CO'},
#   {'num_establishments': 15170,
#    'elec_mwh': 3900070,
#    'gas_mcf': 9535400,
#    'elec_lb_ghg': 6834138251,
#    'gas_lb_ghg': 1144655135,
#    'city': 'Denver',
#    'state': 'CO'},
#   {'num_establishments': 2924,
#    'elec_mwh': 1966737,
#    'gas_mcf': 10473987,
#    'elec_lb_ghg': 3446337146,
#    'gas_lb_ghg': 1257325579,
#    'city': 'Denver',
#    'state': 'CO'}),
#  ({'housing_units': 303582,
#    'elec_mwh': 2249275,
#    'gas_mcf': 7709331,
#    'elec_lb_ghg': 2774303339,
#    'gas_lb_ghg': 925448856,
#    'city': 'Seattle',
#    'state': 'WA'},
#   {'num_establishments': 12286,
#    'elec_mwh': 3168386,
#    'gas_mcf': 5780070,
#    'elec_lb_ghg': 3907953724,
#    'gas_lb_ghg': 693855127,
#    'city': 'Seattle',
#    'state': 'WA'},
#   {'num_establishments': 3462,
#    'elec_mwh': 1181476,
#    'gas_mcf': 3647540,
#    'elec_lb_ghg': 1457257660,
#    'gas_lb_ghg': 437860549,
#    'city': 'Seattle',
#    'state': 'WA'}),
#  ({'city': 'Nashville', 'state': 'TN', 'elec_mwh': 'no_info'},
#   {'city': 'Nashville', 'state': 'TN', 'elec_mwh': 'no_info'},
#   {'city': 'Nashville', 'state': 'TN', 'elec_mwh': 'no_info'}),
#  ({'housing_units': 276546,
#    'elec_mwh': 2668055,
#    'gas_mcf': 11378663,
#    'elec_lb_ghg': 5141707072,
#    'gas_lb_ghg': 1365925334,
#    'city': 'Washington',
#    'state': 'DC'},
#   {'num_establishments': 10407,
#    'elec_mwh': 4973947,
#    'gas_mcf': 10153365,
#    'elec_lb_ghg': 9585476023,
#    'gas_lb_ghg': 1218837317,
#    'city': 'Washington',
#    'state': 'DC'},
#   {'num_establishments': 1459,
#    'elec_mwh': 106489,
#    'gas_mcf': 0,
#    'elec_lb_ghg': 205218514,
#    'gas_lb_ghg': 0,
#    'city': 'Washington',
#    'state': 'DC'}),
#  ({'housing_units': 219073,
#    'elec_mwh': 2679591,
#    'gas_mcf': 7354519,
#    'elec_lb_ghg': 3441451388,
#    'gas_lb_ghg': 882856215,
#    'city': 'Las Vegas',
#    'state': 'NV'},
#   {'num_establishments': 6432,
#    'elec_mwh': 1333362,
#    'gas_mcf': 3697315,
#    'elec_lb_ghg': 1712463053,
#    'gas_lb_ghg': 443835620,
#    'city': 'Las Vegas',
#    'state': 'NV'},
#   {'num_establishments': 1448,
#    'elec_mwh': 381058,
#    'gas_mcf': 516734,
#    'elec_lb_ghg': 489400869,
#    'gas_lb_ghg': 62030117,
#    'city': 'Las Vegas',
#    'state': 'NV'}),
#  ({'housing_units': 256789,
#    'elec_mwh': 2200097,
#    'gas_mcf': 7708516,
#    'elec_lb_ghg': 2713645609,
#    'gas_lb_ghg': 925350994,
#    'city': 'Portland',
#    'state': 'OR'},
#   {'num_establishments': 11628,
#    'elec_mwh': 1979731,
#    'gas_mcf': 4204847,
#    'elec_lb_ghg': 2441841185,
#    'gas_lb_ghg': 504761122,
#    'city': 'Portland',
#    'state': 'OR'},
#   {'num_establishments': 3327,
#    'elec_mwh': 2308797,
#    'gas_mcf': 10507101,
#    'elec_lb_ghg': 2847718874,
#    'gas_lb_ghg': 1261300737,
#    'city': 'Portland',
#    'state': 'OR'}),
#  ({'city': 'Louisville', 'state': 'KY', 'elec_mwh': 'no_info'},
#   {'city': 'Louisville', 'state': 'KY', 'elec_mwh': 'no_info'},
#   {'city': 'Louisville', 'state': 'KY', 'elec_mwh': 'no_info'}),
#  ({'housing_units': 235117,
#    'elec_mwh': 2931106,
#    'gas_mcf': 10044989,
#    'elec_lb_ghg': 6219397035,
#    'gas_lb_ghg': 1205827467,
#    'city': 'Oklahoma City',
#    'state': 'OK'},
#   {'num_establishments': 9705,
#    'elec_mwh': 3071629,
#    'gas_mcf': 5842205,
#    'elec_lb_ghg': 6517567999,
#    'gas_lb_ghg': 701313962,
#    'city': 'Oklahoma City',
#    'state': 'OK'},
#   {'num_establishments': 7277,
#    'elec_mwh': 2267246,
#    'gas_mcf': 24174694,
#    'elec_lb_ghg': 4810779723,
#    'gas_lb_ghg': 2901995391,
#    'city': 'Oklahoma City',
#    'state': 'OK'}),
#  ({'housing_units': 202265,
#    'elec_mwh': 1886622,
#    'gas_mcf': 3806511,
#    'elec_lb_ghg': 2423026492,
#    'gas_lb_ghg': 456943866,
#    'city': 'Tucson',
#    'state': 'AZ'},
#   {'num_establishments': 7556,
#    'elec_mwh': 1118971,
#    'gas_mcf': 2015964,
#    'elec_lb_ghg': 1437116550,
#    'gas_lb_ghg': 242001719,
#    'city': 'Tucson',
#    'state': 'AZ'},
#   {'num_establishments': 1621,
#    'elec_mwh': 376803,
#    'gas_mcf': 497296,
#    'elec_lb_ghg': 483935018,
#    'gas_lb_ghg': 59696734,
#    'city': 'Tucson',
#    'state': 'AZ'}),
#  ({'housing_units': 189445,
#    'elec_mwh': 2003916,
#    'gas_mcf': 7658622,
#    'elec_lb_ghg': 3179881940,
#    'gas_lb_ghg': 919361621,
#    'city': 'Atlanta',
#    'state': 'GA'},
#   {'num_establishments': 9352,
#    'elec_mwh': 3657626,
#    'gas_mcf': 4098771,
#    'elec_lb_ghg': 5804044811,
#    'gas_lb_ghg': 492027483,
#    'city': 'Atlanta',
#    'state': 'GA'},
#   {'num_establishments': 1880,
#    'elec_mwh': 420572,
#    'gas_mcf': 1983839,
#    'elec_lb_ghg': 667377985,
#    'gas_lb_ghg': 238145418,
#    'city': 'Atlanta',
#    'state': 'GA'}),
#  ({'housing_units': 220717,
#    'elec_mwh': 1443155,
#    'gas_mcf': 10327301,
#    'elec_lb_ghg': 1853472760,
#    'gas_lb_ghg': 1239717062,
#    'city': 'Albuquerque',
#    'state': 'NM'},
#   {'num_establishments': 9045,
#    'elec_mwh': 2106381,
#    'gas_mcf': 6201235,
#    'elec_lb_ghg': 2705267404,
#    'gas_lb_ghg': 744412979,
#    'city': 'Albuquerque',
#    'state': 'NM'},
#   {'num_establishments': 1907,
#    'elec_mwh': 1051897,
#    'gas_mcf': 2232251,
#    'elec_lb_ghg': 1350972725,
#    'gas_lb_ghg': 267965392,
#    'city': 'Albuquerque',
#    'state': 'NM'}),
#  ({'housing_units': 163926,
#    'elec_mwh': 1248953,
#    'gas_mcf': 5674950,
#    'elec_lb_ghg': 1672359806,
#    'gas_lb_ghg': 681236321,
#    'city': 'Fresno',
#    'state': 'CA'},
#   {'num_establishments': 6081,
#    'elec_mwh': 956898,
#    'gas_mcf': 2543025,
#    'elec_lb_ghg': 1281295004,
#    'gas_lb_ghg': 305271598,
#    'city': 'Fresno',
#    'state': 'CA'},
#   {'num_establishments': 1748,
#    'elec_mwh': 334399,
#    'gas_mcf': 5080399,
#    'elec_lb_ghg': 447763966,
#    'gas_lb_ghg': 609864713,
#    'city': 'Fresno',
#    'state': 'CA'}),
#  ({'housing_units': 179377,
#    'elec_mwh': 1360998,
#    'gas_mcf': 5659096,
#    'elec_lb_ghg': 1822389842,
#    'gas_lb_ghg': 679333135,
#    'city': 'Sacramento',
#    'state': 'CA'},
#   {'num_establishments': 5795,
#    'elec_mwh': 923123,
#    'gas_mcf': 2819642,
#    'elec_lb_ghg': 1236070021,
#    'gas_lb_ghg': 338477360,
#    'city': 'Sacramento',
#    'state': 'CA'},
#   {'num_establishments': 1432,
#    'elec_mwh': 294373,
#    'gas_mcf': 4472293,
#    'elec_lb_ghg': 394168243,
#    'gas_lb_ghg': 536866118,
#    'city': 'Sacramento',
#    'state': 'CA'}),
#  ({'housing_units': 163850,
#    'elec_mwh': 805726,
#    'gas_mcf': 4859162,
#    'elec_lb_ghg': 1078874360,
#    'gas_lb_ghg': 583306829,
#    'city': 'Long Beach',
#    'state': 'CA'},
#   {'num_establishments': 5468,
#    'elec_mwh': 712853,
#    'gas_mcf': 1144095,
#    'elec_lb_ghg': 954517548,
#    'gas_lb_ghg': 137340259,
#    'city': 'Long Beach',
#    'state': 'CA'},
#   {'num_establishments': 6090,
#    'elec_mwh': 428329,
#    'gas_mcf': 6507428,
#    'elec_lb_ghg': 573536086,
#    'gas_lb_ghg': 781169202,
#    'city': 'Long Beach',
#    'state': 'CA'}),
#  ({'housing_units': 172034,
#    'elec_mwh': 2252563,
#    'gas_mcf': 1203918,
#    'elec_lb_ghg': 2893011444,
#    'gas_lb_ghg': 144521549,
#    'city': 'Mesa',
#    'state': 'AZ'},
#   {'num_establishments': 5227,
#    'elec_mwh': 1432441,
#    'gas_mcf': 1332179,
#    'elec_lb_ghg': 1839711856,
#    'gas_lb_ghg': 159918340,
#    'city': 'Mesa',
#    'state': 'AZ'},
#   {'num_establishments': 1552,
#    'elec_mwh': 388691,
#    'gas_mcf': 512986,
#    'elec_lb_ghg': 499203774,
#    'gas_lb_ghg': 61580241,
#    'city': 'Mesa',
#    'state': 'AZ'}),
#  ({'housing_units': 196505,
#    'elec_mwh': 2034047,
#    'gas_mcf': 8818980,
#    'elec_lb_ghg': 3662951479,
#    'gas_lb_ghg': 1058654117,
#    'city': 'Kansas City',
#    'state': 'MO'},
#   {'num_establishments': 7508,
#    'elec_mwh': 2624112,
#    'gas_mcf': 55266,
#    'elec_lb_ghg': 4725552190,
#    'gas_lb_ghg': 6634223,
#    'city': 'Kansas City',
#    'state': 'MO'},
#   {'num_establishments': 1869,
#    'elec_mwh': 734800,
#    'gas_mcf': 3460026,
#    'elec_lb_ghg': 1323242410,
#    'gas_lb_ghg': 415350817,
#    'city': 'Kansas City',
#    'state': 'MO'}),
#  ({'housing_units': 169470,
#    'elec_mwh': 1879693,
#    'gas_mcf': 4511363,
#    'elec_lb_ghg': 2034512109,
#    'gas_lb_ghg': 541556113,
#    'city': 'Omaha',
#    'state': 'NE'},
#   {'num_establishments': 6606,
#    'elec_mwh': 2158577,
#    'gas_mcf': 3037821,
#    'elec_lb_ghg': 2336366059,
#    'gas_lb_ghg': 364668177,
#    'city': 'Omaha',
#    'state': 'NE'},
#   {'num_establishments': 1492,
#    'elec_mwh': 1236449,
#    'gas_mcf': 10089905,
#    'elec_lb_ghg': 1338287436,
#    'gas_lb_ghg': 1211219363,
#    'city': 'Omaha',
#    'state': 'NE'}),
#  ({'housing_units': 167049,
#    'elec_mwh': 1114033,
#    'gas_mcf': 14484997,
#    'elec_lb_ghg': 1899308439,
#    'gas_lb_ghg': 1738818014,
#    'city': 'Cleveland',
#    'state': 'OH'},
#   {'num_establishments': 6965,
#    'elec_mwh': 594990,
#    'gas_mcf': 5609142,
#    'elec_lb_ghg': 1014395339,
#    'gas_lb_ghg': 673336477,
#    'city': 'Cleveland',
#    'state': 'OH'},
#   {'num_establishments': 2751,
#    'elec_mwh': 1292030,
#    'gas_mcf': 7074245,
#    'elec_lb_ghg': 2202773934,
#    'gas_lb_ghg': 849211375,
#    'city': 'Cleveland',
#    'state': 'OH'}),
#  ({'housing_units': 167494,
#    'elec_mwh': 2368923,
#    'gas_mcf': 3951760,
#    'elec_lb_ghg': 2936739018,
#    'gas_lb_ghg': 474379948,
#    'city': 'Virginia Beach',
#    'state': 'VA'},
#   {'num_establishments': None,
#    'elec_mwh': None,
#    'gas_mcf': None,
#    'elec_lb_ghg': None,
#    'gas_lb_ghg': None,
#    'city': 'Virginia Beach',
#    'state': 'VA'},
#   {'num_establishments': 1201,
#    'elec_mwh': 142500,
#    'gas_mcf': 713968,
#    'elec_lb_ghg': 176656079,
#    'gas_lb_ghg': 85706679,
#    'city': 'Virginia Beach',
#    'state': 'VA'}),
#  ({'housing_units': 161487,
#    'elec_mwh': 1901135,
#    'gas_mcf': 156051,
#    'elec_lb_ghg': 2682521578,
#    'gas_lb_ghg': 18732827,
#    'city': 'Miami',
#    'state': 'FL'},
#   {'num_establishments': 8815,
#    'elec_mwh': 2196417,
#    'gas_mcf': 1851831,
#    'elec_lb_ghg': 3099167782,
#    'gas_lb_ghg': 222298743,
#    'city': 'Miami',
#    'state': 'FL'},
#   {'num_establishments': 2039,
#    'elec_mwh': 237401,
#    'gas_mcf': 1468378,
#    'elec_lb_ghg': 334975738,
#    'gas_lb_ghg': 176268046,
#    'city': 'Miami',
#    'state': 'FL'}),
#  ({'housing_units': 159072,
#    'elec_mwh': 728202,
#    'gas_mcf': 5058703,
#    'elec_lb_ghg': 975068890,
#    'gas_lb_ghg': 607260311,
#    'city': 'Oakland',
#    'state': 'CA'},
#   {'num_establishments': 7043,
#    'elec_mwh': 984793,
#    'gas_mcf': 4181424,
#    'elec_lb_ghg': 1318646783,
#    'gas_lb_ghg': 501949404,
#    'city': 'Oakland',
#    'state': 'CA'},
#   {'num_establishments': 1490,
#    'elec_mwh': 203206,
#    'gas_mcf': 3087235,
#    'elec_lb_ghg': 272095316,
#    'gas_lb_ghg': 370600013,
#    'city': 'Oakland',
#    'state': 'CA'}),
#  ({'housing_units': 172932,
#    'elec_mwh': 1813183,
#    'gas_mcf': 4415618,
#    'elec_lb_ghg': 2247792061,
#    'gas_lb_ghg': 530062684,
#    'city': 'Raleigh',
#    'state': 'NC'},
#   {'num_establishments': 6252,
#    'elec_mwh': 1890778,
#    'gas_mcf': 1417929,
#    'elec_lb_ghg': 2343986079,
#    'gas_lb_ghg': 170212065,
#    'city': 'Raleigh',
#    'state': 'NC'},
#   {'num_establishments': 1466,
#    'elec_mwh': 189729,
#    'gas_mcf': 732236,
#    'elec_lb_ghg': 235205421,
#    'gas_lb_ghg': 87899547,
#    'city': 'Raleigh',
#    'state': 'NC'}),
#  ({'housing_units': 164916,
#    'elec_mwh': 1927512,
#    'gas_mcf': 7319678,
#    'elec_lb_ghg': 4089911438,
#    'gas_lb_ghg': 878673828,
#    'city': 'Tulsa',
#    'state': 'OK'},
#   {'num_establishments': 7472,
#    'elec_mwh': 2451487,
#    'gas_mcf': 4539003,
#    'elec_lb_ghg': 5201714034,
#    'gas_lb_ghg': 544874084,
#    'city': 'Tulsa',
#    'state': 'OK'},
#   {'num_establishments': 4309,
#    'elec_mwh': 1545877,
#    'gas_mcf': 16483037,
#    'elec_lb_ghg': 3280134984,
#    'gas_lb_ghg': 1978668148,
#    'city': 'Tulsa',
#    'state': 'OK'}),
#  ({'housing_units': 169801,
#    'elec_mwh': 982969,
#    'gas_mcf': 10103477,
#    'elec_lb_ghg': 1063930425,
#    'gas_lb_ghg': 1212848536,
#    'city': 'Minneapolis',
#    'state': 'MN'},
#   {'num_establishments': 7164,
#    'elec_mwh': 1580941,
#    'gas_mcf': 9405753,
#    'elec_lb_ghg': 1711153109,
#    'gas_lb_ghg': 1129091909,
#    'city': 'Minneapolis',
#    'state': 'MN'},
#   {'num_establishments': 1638,
#    'elec_mwh': 383886,
#    'gas_mcf': 2945919,
#    'elec_lb_ghg': 415504469,
#    'gas_lb_ghg': 353636091,
#    'city': 'Minneapolis',
#    'state': 'MN'}),
#  ({'housing_units': 176399,
#    'elec_mwh': 1406871,
#    'gas_mcf': 12006874,
#    'elec_lb_ghg': 2465275945,
#    'gas_lb_ghg': 1441337529,
#    'city': 'Colorado Springs',
#    'state': 'CO'},
#   {'num_establishments': 6132,
#    'elec_mwh': 605460,
#    'gas_mcf': 3962859,
#    'elec_lb_ghg': 1060953946,
#    'gas_lb_ghg': 475712266,
#    'city': 'Colorado Springs',
#    'state': 'CO'},
#   {'num_establishments': 1664,
#    'elec_mwh': 358976,
#    'gas_mcf': 1911750,
#    'elec_lb_ghg': 629038064,
#    'gas_lb_ghg': 229491665,
#    'city': 'Colorado Springs',
#    'state': 'CO'}),
#  ({'housing_units': 309355,
#    'elec_mwh': 1912612,
#    'gas_mcf': 570569,
#    'elec_lb_ghg': 3779848328,
#    'gas_lb_ghg': 68492693,
#    'city': 'Honolulu',
#    'state': 'HI'},
#   {'num_establishments': 7766,
#    'elec_mwh': 2200305,
#    'gas_mcf': 1849831,
#    'elec_lb_ghg': 4348409245,
#    'gas_lb_ghg': 222058637,
#    'city': 'Honolulu',
#    'state': 'HI'},
#   {'num_establishments': 2683,
#    'elec_mwh': 2562676,
#    'gas_mcf': 373179,
#    'elec_lb_ghg': 5064554321,
#    'gas_lb_ghg': 44797355,
#    'city': 'Honolulu',
#    'state': 'HI'}),
#  ({'housing_units': 134895,
#    'elec_mwh': 1923102,
#    'gas_mcf': 2071627,
#    'elec_lb_ghg': 2575036519,
#    'gas_lb_ghg': 248683627,
#    'city': 'Arlington',
#    'state': 'TX'},
#   {'num_establishments': 4871,
#    'elec_mwh': 1227693,
#    'gas_mcf': 1065277,
#    'elec_lb_ghg': 1643882787,
#    'gas_lb_ghg': 127878702,
#    'city': 'Arlington',
#    'state': 'TX'},
#   {'num_establishments': 1547,
#    'elec_mwh': 462794,
#    'gas_mcf': 6732608,
#    'elec_lb_ghg': 619681188,
#    'gas_lb_ghg': 808200348,
#    'city': 'Arlington',
#    'state': 'TX'})]

# %% [markdown]
# Prepare residential data for the database. This includes selecting residential sector information from each city's  tuple and providing each city with a corresponding city_id (population rank).

# %%
list_of_residential_1 = []
for i in energy_data_1:
    res_info = i[0]
    list_of_residential_1.append(res_info)

# %%
for index, item in enumerate(list_of_residential_1):
    list_of_residential_1[index].update( {'city_id' : index+4501} )

# %% [markdown]
# Check residential data to make sure it has been modified correctly.

# %%
list_of_residential_1[5]
# Out:
# {'housing_units': 582511,
#  'elec_mwh': 4271528,
#  'gas_mcf': 33972181,
#  'elec_lb_ghg': 8231817377,
#  'gas_lb_ghg': 4078112104,
#  'city': 'Philadelphia',
#  'state': 'PA',
#  'city_id': 4506}

# %%
list_of_residential_1[-1] #id should match city_names index + 1
# Out:
# {'housing_units': 134895,
#  'elec_mwh': 1923102,
#  'gas_mcf': 2071627,
#  'elec_lb_ghg': 2575036519,
#  'gas_lb_ghg': 248683627,
#  'city': 'Arlington',
#  'state': 'TX',
#  'city_id': 4550}

# %% [markdown]
# Loop through residential data to check for missing values and return clean list of dictionaries.

# %%
list_of_residential_1 = [item for item in list_of_residential_1 if item['elec_mwh'] != 'no_info']

# %% [markdown]
# Check the amount of missing values.

# %%
len(list_of_residential_1)
# Out:
# 47

# %%
list_of_residential_1[5] #id should match city_names index + 1
# Out:
# {'housing_units': 582511,
#  'elec_mwh': 4271528,
#  'gas_mcf': 33972181,
#  'elec_lb_ghg': 8231817377,
#  'gas_lb_ghg': 4078112104,
#  'city': 'Philadelphia',
#  'state': 'PA',
#  'city_id': 4506}

# %% [markdown]
# Follow same directions in order to prepare commercial data.

# %%
list_of_commercial_1 = []
for i in energy_data_1:
    com_info = i[1]
    list_of_commercial_1.append(com_info)

# %%
for index, item in enumerate(list_of_commercial_1):
    list_of_commercial_1[index].update( {'city_id' : index+4501} )

# %%
list_of_commercial_1 = [item for item in list_of_commercial_1 if item['elec_mwh'] != 'no_info']

# %%
list_of_commercial_1[0]
# Out:
# {'num_establishments': 68,
#  'elec_mwh': 13653,
#  'gas_mcf': 33079,
#  'elec_lb_ghg': 17820142,
#  'gas_lb_ghg': 3970932,
#  'city': 'New Haven',
#  'state': 'MI',
#  'city_id': 4501}

# %%
len(list_of_commercial_1)
# Out:
# 482

# %% [markdown]
# Follow same directions in order to prepare industrial data.

# %%
list_of_industrial_1 = []
for i in energy_data_1:
    ind_info = i[2]
    list_of_industrial_1.append(ind_info)

# %%
for index, item in enumerate(list_of_industrial_1):
    list_of_industrial_1[index].update( {'city_id' : index+4501} )

# %%
list_of_industrial_1 = [item for item in list_of_industrial_1 if item['elec_mwh'] != 'no_info']

# %%
len(list_of_industrial_1)
# Out:
# 482

# %%
list_of_industrial_1[-1]
# Out:
# {'num_establishments': 9,
#  'elec_mwh': 4178,
#  'gas_mcf': 16126,
#  'elec_lb_ghg': 5180018,
#  'gas_lb_ghg': 1935845,
#  'city': 'Newport',
#  'state': 'NC',
#  'city_id': 5000}

# %% [markdown]
# Insert residential data dictionaries into the residential_energy_A table.

# %%
add_residential = ("INSERT INTO residential_energy_A "
               "(housing_units, elec_mwh, gas_mcf, elec_lb_ghg, gas_lb_ghg, city, state, city_id) "
               "VALUES (%(housing_units)s, %(elec_mwh)s, %(gas_mcf)s, %(elec_lb_ghg)s, %(gas_lb_ghg)s, %(city)s, %(state)s, %(city_id)s)")

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.passwd,
    database = db_name
)
cur = cnx.cursor()

# %%
cur.executemany(add_residential, list_of_residential_1)
cnx.commit()

# %%
cur.close()
cnx.close()

# %% [markdown]
# Insert commercial data into commercial_energy_A table.

# %%
add_commercial = ("INSERT INTO commercial_energy_A "
               "(num_establishments, elec_mwh, gas_mcf, elec_lb_ghg, gas_lb_ghg, city, state, city_id) "
               "VALUES (%(num_establishments)s, %(elec_mwh)s, %(gas_mcf)s, %(elec_lb_ghg)s, %(gas_lb_ghg)s, %(city)s, %(state)s, %(city_id)s)")

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.passwd,
    database = db_name
)
cur = cnx.cursor()

# %%
cur.executemany(add_commercial, list_of_commercial_1)
cnx.commit()

# %% [markdown]
# Insert industrial data into industrial_energy_A table.

# %%
add_industrial = ("INSERT INTO industrial_energy_A "
               "(num_establishments, elec_mwh, gas_mcf, elec_lb_ghg, gas_lb_ghg, city, state, city_id) "
               "VALUES (%(num_establishments)s, %(elec_mwh)s, %(gas_mcf)s, %(elec_lb_ghg)s, %(gas_lb_ghg)s, %(city)s, %(state)s, %(city_id)s)")

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    passwd = config.passwd,
    database = db_name
)
cur = cnx.cursor()

# %%
cur.executemany(add_industrial, list_of_industrial_1)
cnx.commit()

# %%
cnx.close()
